# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from webdriver_manager.chrome import ChromeDriverManager
from splinter import Browser
from selenium import webdriver

# %%
# url
url = 'https://redplanetscience.com/'

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
browser.visit(url)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Driver [/Users/monicabustillos/.wdm/drivers/chromedriver/mac64/89.0.4389.23/chromedriver] found in cache

# %%
# retrieve page
# response = requests.get(url)
html = browser.html

# %%
# beautiful soup object
soup = BeautifulSoup(html,'html.parser')

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
#   <link href="css/font.css" rel="stylesheet" type="text/css"/>
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
#   <title>
#    News - Mars Exploration Program
#   </title>
#  </head>
#  <body>
#   <div class="col-md-12">
#    <div class="row">
#     <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#      <div class="container-fluid">
#       <a class="navbar-brand" href="#">
# ...

# %%
# iterable list 
results = soup.find_all('div', class_ = 'list_text')
results
# Out:
# [<div class="list_text">
#  <div class="list_date">March 30, 2021</div>
#  <div class="content_title">Mars 2020 Unwrapped and Ready for More Testing</div>
#  <div class="article_teaser_body">In time-lapse video, bunny-suited engineers remove the inner layer of protective foil on NASA's Mars 2020 rover after it was relocated for testing.</div>
#  </div>,
#  <div class="list_text">
#  <div class="list_date">March 29, 2021</div>
#  <div class="content_title">5 Hidden Gems Are Riding Aboard NASA's Perseverance Rover</div>
#  <div class="article_teaser_body">The symbols, mottos, and small objects added to the agency's newest Mars rover serve a variety of purposes, from functional to decorative.</div>
#  </div>,
#  <div class="list_text">
#  <div class="list_date">March 27, 2021</div>
#  <div class="content_title">NASA InSight's 'Mole' Is Out of Sight</div>
# ...

# %%
# loop through results
for result in results:
    try:
#       identify and return title and paragraph 
        news_title = result.find('div', class_ = 'content_title').text
        news_p = result.find('div', class_ = 'article_teaser_body').text
        
        if (news_title and news_p):
            print('-----------------')
            print(news_title)
            print(news_p)
    except AttributeError as e:
        print(e)
# Out:
# -----------------
# Mars 2020 Unwrapped and Ready for More Testing
# In time-lapse video, bunny-suited engineers remove the inner layer of protective foil on NASA's Mars 2020 rover after it was relocated for testing.
# -----------------
# 5 Hidden Gems Are Riding Aboard NASA's Perseverance Rover
# The symbols, mottos, and small objects added to the agency's newest Mars rover serve a variety of purposes, from functional to decorative.
# -----------------
# NASA InSight's 'Mole' Is Out of Sight
# Now that the heat probe is just below the Martian surface, InSight's arm will scoop some additional soil on top to help it keep digging so it can take Mars' temperature.
# -----------------
# NASA's Mars 2020 Heads Into the Test Chamber
# In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.
# -----------------
# HiRISE Views NASA's InSight and Curiosity on Mars
# ...

# %%
# JPL Mars Space Images - Featured Image

# %%
# url
url2 = 'https://spaceimages-mars.com/'
browser.visit(url2)
html = browser.html
soup = BeautifulSoup(html,'html.parser')

# %%
# finding image url 
images = soup.find_all('img', class_ = 'headerimage fade-in')
featured_image_url = images[0].get('src')

# %%
print(images)
print(featured_image_url)
# Out:
# [<img class="headerimage fade-in" src="image/featured/mars3.jpg"/>]
# image/featured/mars3.jpg

# %%
# Mars Facts

# %%
url3 = 'https://galaxyfacts-mars.com/'
tables = pd.read_html(url3)
tables
# Out:
# [                         0                1                2
#  0  Mars - Earth Comparison             Mars            Earth
#  1                Diameter:         6,779 km        12,742 km
#  2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
#  3                   Moons:                2                1
#  4       Distance from Sun:   227,943,824 km   149,598,262 km
#  5          Length of Year:   687 Earth days      365.24 days
#  6             Temperature:     -87 to -5 °C      -88 to 58°C,
#                        0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
#  3                Moons:          2 ( Phobos & Deimos )
#  4       Orbit Distance:       227,943,824 km (1.38 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                   -87 to -5 °C
# ...

# %%
#  list to df
df = tables[0]

df= df.T
df.columns = df.iloc[0]
df = df.reset_index()
df
# Out:
# Diameter:          1  Mars - Earth Comparison  Diameter:            Mass:  \
# 0          Diameter:  Mars - Earth Comparison  Diameter:            Mass:
# 1           6,779 km                     Mars   6,779 km  6.39 × 10^23 kg
# 2          12,742 km                    Earth  12,742 km  5.97 × 10^24 kg
#
# Diameter:  Moons:  Distance from Sun:  Length of Year:  Temperature:
# 0          Moons:  Distance from Sun:  Length of Year:  Temperature:
# 1               2      227,943,824 km   687 Earth days  -87 to -5 °C
# 2               1      149,598,262 km      365.24 days   -88 to 58°C

# %%
df = df.iloc[1:] 
# df.columns = df.columns.str.replace('Diameter', 'Index')
df
# Out:
# Diameter:          1 Mars - Earth Comparison  Diameter:            Mass:  \
# 1           6,779 km                    Mars   6,779 km  6.39 × 10^23 kg
# 2          12,742 km                   Earth  12,742 km  5.97 × 10^24 kg
#
# Diameter: Moons: Distance from Sun: Length of Year:  Temperature:
# 1              2     227,943,824 km  687 Earth days  -87 to -5 °C
# 2              1     149,598,262 km     365.24 days   -88 to 58°C

# %%
html_table = df.to_html()

# %%
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>Diameter:</th>\n      <th>nan</th>\n      <th>Mars - Earth Comparison</th>\n      <th>Index:</th>\n      <th>Mass:</th>\n      <th>Moons:</th>\n      <th>Distance from Sun:</th>\n      <th>Length of Year:</th>\n      <th>Temperature:</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>6,779 km</td>\n      <td>Mars</td>\n      <td>6,779 km</td>\n      <td>6.39 × 10^23 kg</td>\n      <td>2</td>\n      <td>227,943,824 km</td>\n      <td>687 Earth days</td>\n      <td>-87 to -5 °C</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>12,742 km</td>\n      <td>Earth</td>\n      <td>12,742 km</td>\n      <td>5.97 × 10^24 kg</td>\n      <td>1</td>\n      <td>149,598,262 km</td>\n      <td>365.24 days</td>\n      <td>-88 to 58°C</td>\n    </tr>\n  </tbody>\n</table>'

# %%
# Mars Hemispheres

# %%
# Visit the astrogeology site here to obtain high resolution images
# for each of Mar's hemispheres.


# You will need to click each of the links to the hemispheres in 
# order to find the image url to the full resolution image.


# Save both the image url string for the full resolution hemisphere 
# image, and the Hemisphere title containing the hemisphere name. Use 
# a Python dictionary to store the data using the keys img_url and title.


# Append the dictionary with the image url string and the hemisphere 
# title to a list. This list will contain one dictionary for each
# hemisphere.

# %%
dictionary = {}
# mars hemispheres link 
url4 = 'https://marshemispheres.com/'
browser.visit(url4)
html = browser.html
soup = BeautifulSoup(html,'html.parser')

# identifying clicking on image
hemispheres_image = soup.find('img', class_ = 'thumb')
hemispheres_image.click()
featured_image_url = images[0].get('src') 

# next page clicking on open button 
open_button = soup.find_element_by_id('wide-image-toggle')
open_button.click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-18b7d540bce9> in <module>
#       8 # identifying clicking on image
#       9 hemispheres_image = soup.find('thumb')
# ---> 10 hemispheres_image.click()
#      11 featured_image_url = images[0].get('src')
#      12
#
# AttributeError: 'NoneType' object has no attribute 'click'

# %%
type(hemispheres_image)
# Out:
# bs4.element.Tag
